# %%
import pandas
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
cfpb = pandas.read_csv("complaints_dec_2014.csv")

# %%
cfpb
# Out:
#        Complaint ID                  Product  \
# 0           1177167          Debt collection
# 1           1177166          Debt collection
# 2           1177165          Debt collection
# 3           1177164          Debt collection
# 4           1177163          Debt collection
# 5           1177162          Debt collection
# 6           1177154              Credit card
# 7           1177143          Debt collection
# 8           1177140          Debt collection
# 9           1177139          Debt collection
# 10          1177136          Debt collection
# 11          1177128  Bank account or service
# 12          1177125          Debt collection
# 13          1177124          Debt collection
# 14          1177116          Debt collection
# 15          1177114          Debt collection
# 16          1177196         Credit reporting
# 17          1177113          Debt collection
# 18          1177112          Debt collection
# 19          1177101              Credit card
# ...

# %%
cfpb.Product.unique()
# Out:
# array(['Debt collection', 'Credit card', 'Bank account or service',
#        'Credit reporting', 'Mortgage', 'Money transfers', 'Consumer loan',
#        'Student loan', 'Payday loan', 'Prepaid card',
#        'Other financial service'], dtype=object)

# %%
cfpb.shape
# Out:
# (11543, 14)

# %%
cfpb["Product"].value_counts()
# Out:
# Mortgage                   3002
# Debt collection            2942
# Credit reporting           2113
# Bank account or service    1136
# Credit card                1100
# Consumer loan               578
# Student loan                340
# Payday loan                 141
# Money transfers             107
# Prepaid card                 70
# Other financial service      14
# dtype: int64

# %%
cfpb["Product"].value_counts().plot(kind="bar", figsize=(18,5), y='Number of complaints')

# %%
cfpb["Company"].value_counts()
# Out:
# Bank of America              766
# Equifax                      737
# Experian                     675
# TransUnion                   604
# Wells Fargo                  598
# JPMorgan Chase               545
# Ocwen                        408
# Citibank                     403
# Nationstar Mortgage          357
# Capital One                  252
# U.S. Bancorp                 203
# Navient                      177
# GE Capital Retail            175
# Green Tree Servicing, LLC    174
# Encore Capital Group         156
# ...
# Texas Higher Education Coordinating Board    1
# Credit Regulating Services, Inc.             1
# Coastline Financial Resources, LLC           1
# Lafayette General Medical Center             1
# Duck Creek Tribal Financial                  1
# Ann Arbor Credit Bureau, Inc.                1
# Account Control Systems, Inc                 1
# Westgate Arbitration INC                     1
# Eagle Accounts Group, Inc.                   1
# ...

# %%
cfpb["Company"].value_counts()[:10].plot(kind="bar", figsize=(18, 5))

# %%
cfpb["Company response"].value_counts()
# Out:
# Closed with explanation            8185
# Closed with non-monetary relief    1253
# In progress                        1056
# Closed with monetary relief         643
# Closed                              239
# Untimely response                   167
# dtype: int64

# %%
cfpb.
# Out:
# 0     12/31/2014
# 1     12/31/2014
# 2     12/31/2014
# 3     12/31/2014
# 4     12/31/2014
# 5     12/31/2014
# 6     12/31/2014
# 7     12/31/2014
# 8     12/31/2014
# 9     12/31/2014
# 10    12/31/2014
# 11    12/31/2014
# 12    12/31/2014
# 13    12/31/2014
# 14    12/31/2014
# ...
# 11528    12/01/2014
# 11529    12/01/2014
# 11530    12/01/2014
# 11531    12/01/2014
# 11532    12/01/2014
# 11533    12/01/2014
# 11534    12/01/2014
# 11535    12/01/2014
# 11536    12/01/2014
# 11537    12/01/2014
# 11538    12/01/2014
# 11539    12/01/2014
# 11540    12/01/2014
# 11541    12/01/2014
# 11542    12/01/2014
# Name: Date received, Length: 11543, dtype: object
