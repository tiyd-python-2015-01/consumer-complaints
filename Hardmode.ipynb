# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
census_data = pd.read_csv("NST_EST2014_ALLDATA.csv")

# %%
consumer_complaints = pd.read_csv("complaints_dec_2014.csv")
# Out:
#      Complaint ID                  Product                  Sub-product  \
# 23        1177085                 Mortgage  Conventional fixed mortgage
# 30        1177035  Bank account or service             Checking account
# 37        1176982          Debt collection                      Medical
# 69        1176894              Credit card                          NaN
# 77        1176871          Debt collection                  Credit card
# 79        1176867              Payday loan                          NaN
# 84        1176853             Student loan     Non-federal student loan
# 93        1176820  Bank account or service             Checking account
# 106       1176757              Credit card                          NaN
# 144       1176563  Bank account or service   Other bank product/service
#
#                                         Issue  \
# 23   Loan servicing, payments, escrow account
# 30   Making/receiving payments, sending money
# ...

# %%
consumer_complaints[:]
# Out:
#        Complaint ID                  Product  \
# 0           1177167          Debt collection
# 1           1177166          Debt collection
# 2           1177165          Debt collection
# 3           1177164          Debt collection
# 4           1177163          Debt collection
# 5           1177162          Debt collection
# 6           1177154              Credit card
# 7           1177143          Debt collection
# 8           1177140          Debt collection
# 9           1177139          Debt collection
# 10          1177136          Debt collection
# 11          1177128  Bank account or service
# 12          1177125          Debt collection
# 13          1177124          Debt collection
# 14          1177116          Debt collection
# 15          1177114          Debt collection
# 16          1177196         Credit reporting
# 17          1177113          Debt collection
# 18          1177112          Debt collection
# 19          1177101              Credit card
# ...

# %%
consumer_complaints.State.unique()
# Out:
# array(['TX', 'GA', 'AZ', 'NY', 'PA', 'AL', 'IL', 'VA', 'NJ', 'MN', 'OR',
#        'FL', nan, 'NC', 'CA', 'IN', 'ID', 'NH', 'OK', 'CT', 'WA', 'MA',
#        'NV', 'CO', 'MI', 'NM', 'MO', 'WV', 'OH', 'MS', 'MD', 'VT', 'TN',
#        'DE', 'AK', 'KY', 'LA', 'VI', 'SC', 'UT', 'HI', 'IA', 'SD', 'DC',
#        'KS', 'ND', 'PR', 'WI', 'ME', 'AR', 'RI', 'MT', 'NE', 'AP', 'AS',
#        'WY', 'AE'], dtype=object)

# %%
census_data = pd.read_csv("NST_EST2014_ALLDATA.csv")

# %%
gdp_complaints = pd.read_csv("complaints_by_state.csv", index_col = "State")
gdp_complaints[:]
# Out:
#        Complaints Per capita
# State
# AK             15      51542
# AL            147     180727
# AR             59     115745
# AZ            213     261924
# CA           1591    2050693
# CO            180     273721
# CT            109     233996
# DC             82     105465
# DE             44      58028
# FL           1093     750511
# GA            512     424606
# HI             48      70110
# IA             51     150512
# ID             39      57029
# IL            427     671407
# IN            132     294212
# KS             56     132153
# KY             59     170667
# LA            127     222008
# MA            200      51163
# MD            342     322234
# ME             39      51163
# MI            287     408218
# MN            135     289125
# MO            119     258135
# MS             57      96979
# MT             14      39846
# NC            287     439672
# ND              8      49772
# NE             37      98250
# NH             46      64118
# ...

# %%
census_data[:10]
# Out:
#    SUMLEV REGION DIVISION  STATE              NAME  CENSUS2010POP  \
# 0      10      0        0      0     United States      308745538
# 1      20      1        0      0  Northeast Region       55317240
# 2      20      2        0      0    Midwest Region       66927001
# 3      20      3        0      0      South Region      114555744
# 4      20      4        0      0       West Region       71945553
# 5      40      3        6      1           Alabama        4779736
# 6      40      4        9      2            Alaska         710231
# 7      40      4        8      4           Arizona        6392017
# 8      40      3        7      5          Arkansas        2915918
# 9      40      4        9      6        California       37253956
#
#    ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# 0          308758105        309347057        311721632        314112078
# 1           55318348         55381690         55635670         55832038
# ...

# %%
state_table = pd.read_csv("state_table.csv")

# %%
state_table.abbreviation.unique()
# Out:
# array(['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA', 'HI',
#        'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI',
#        'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC',
#        'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT',
#        'VT', 'VA', 'WA', 'WV', 'WI', 'WY', 'DC'], dtype=object)

# %%
big_state_data = pd.read_csv("statesInProfile_dataExtract.csv")
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-45-7b89b0d5120f> in <module>()
# ----> 1 big_state_data = pd.read_csv("statesInProfile_dataExtract.csv")
#
# ...
